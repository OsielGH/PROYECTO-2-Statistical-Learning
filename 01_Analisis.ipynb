# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import modulos

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#RECORDAR 1: Balancear los datos en función del target.
df['Churn'].value_counts()   ## columan que deseamos predecir valores ver que distribucion tiene
# Out:
# FALSO        2850
# VERDADERO     483
# Name: Churn, dtype: int64

# %% [markdown]
# ## 1) Análisis de Datos   ## no completo, debe completarse para proyecto

# %%
## Verificación de tipos de datos para cada columna
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                      object
# dtype: object

# %%
#obtenemos tipos de datos de columnas de dataframe
categoric_vars, discrete_vars , continues_vars = modulos.getColumnsDataTypes(df=df)

# %%
#Eliminamos variable target.
categoric_vars.remove('Churn')

# %% [markdown]
# ##### 1.1) Análisis de Datos Categóricos

# %% [markdown]
# ##### #fALTARIA REALIZAR LAS GRAFICAS DE VALORES NUMERICOS

# %%
modulos.plotCategoricalVals(df, categoric_vars, y='Churn')

# %% [markdown]
# ##### 1.2) Análisis de Datos Numericos  (Discreto)

# %%
modulos.plotCategoricalVals(df, discrete_vars, y='Churn')

# %% [markdown]
# ##### 1.3) Análisis de Datos Numericos  (Continuas)

# %%
modulos.plotCategoricalVals(df, continues_vars, y='Churn')

# %%
## Debe completar el análisis para las demás variables:
    # * numéricas discretas.
    # * numéticas continuas.
    # * target.
